# %% [markdown]
# # virtual box _ ubuntu 설치
# - https://webnautes.tistory.com/448
#     - 해당 링크 순서대로 진행
#     - 하지만 진행 중 몇가지 문제가 있었음
# - 단 usb 3.0이 안될수도있음(본인은 1.0 check해서 진행
#     ![image](https://user-images.githubusercontent.com/28910538/57113405-5e302b00-6d7f-11e9-8b6d-c7a96d56799b.png)
# - 또한 본인은 다음과 같이 3차원 가속 사용했을때
#     ![image.png](attachment:image.png)
#     - 다음과 같이 화면이 뜨고 부팅화면을 벗어나지 못함
#         - 아마도 gpu 문제일 것으로 추정
#     ![image](https://user-images.githubusercontent.com/28910538/57113524-eadae900-6d7f-11e9-99c7-f0f391d89bef.png)
#     - nvidia dirver가 깔려있지 않은 걸 확인할 수 있음
#         - ![image](https://user-images.githubusercontent.com/28910538/57113693-af8cea00-6d80-11e9-92a4-f49437741462.png)
